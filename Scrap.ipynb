# %% [markdown]
# # Fetching Data From Web

# %% [markdown]
# ### Project 1   [Fetching Text from div]

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://biography.yourdictionary.com/articles/how-did-bruce-lee-die.html"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html data-n-head-ssr="">
# <head>
# ...

# %%
para= soup.p.text

# %%
para
# Out:
# 'With a nickname like “The Dragon,” Bruce Lee undeniably lived at the top of the martial arts pyramid. So, when a powerhouse like him laid down at the age of 32 and never woke again, the world was stunned.'

# %%
all_p = soup.find_all('p')

# %%
for p in all_p:
    print(p.text,"\n")
# Out:
# With a nickname like “The Dragon,” Bruce Lee undeniably lived at the top of the martial arts pyramid. So, when a powerhouse like him laid down at the age of 32 and never woke again, the world was stunned.
#
# One of the most in-depth biographies on Lee makes the assertion that he “wasn’t just an entertainer; he was an evangelist.” That’s quite a testament to Bruce Lee’s impact on other people and their decisions to embark upon a lifelong journey with martial arts.
#
# It seemed as though Bruce Lee could take down a fiery dragon if faced with one. Yet, he died on July 20, 1973 -- at the tender age of 32. How could a man of enviable strength and skill just drop dead in his early thirties? Really, how did Bruce Lee die?
#
# Lee’s final film Enter the Dragon went down in history as one of the most successful martial arts movies of all time. In fact, his hand strikes were so fast, the camera speed had to be adjusted.
#
# ...

# %% [markdown]
# ### Project 2  [Fetching Multiple List tags]

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
table = soup.find('div',{'class':'rankings-block__container full rankings-table'})

# %%
table
# Out:
# <div class="rankings-block__container full rankings-table">
# <table class="table">
# <thead>
# <tr class="table-head">
# <th class="table-head__cell u-text-right">Pos</th>
# <th class="table-head__cell rankings-table__team">
# <span class="u-hide-mobile">Team</span>
# <span class="u-show-mobile">T</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Matches</span>
# <span class="u-show-mobile">M</span>
# </th>
# <th class="table-head__cell u-center-text">
# <span class="u-hide-mobile">Points</span>
# <span class="u-show-mobile">P</span>
# </th>
# <th class="table-head__cell u-text-right rating">
# <span class="u-hide-mobile">Rating</span>
# <span class="u-show-mobile">R</span>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr class="rankings-block__banner">
# <td class="rankings-block__banner--pos">1</td>
# <td class="rankings-block__banner--team-name">
# <span class="flag-30 rankings-block__banner--flag NZ"></span>
# ...

# %%
count = 1
for data in table.find_all('span',{"class":"u-hide-phablet"}):
    print(count,"-->",data.text,"\n")
    count +=1
# Out:
# 1 --> New Zealand
#
# 2 --> Australia
#
# 3 --> India
#
# 4 --> England
#
# 5 --> South Africa
#
# 6 --> Pakistan
#
# 7 --> Bangladesh
#
# 8 --> West Indies
#
# 9 --> Sri Lanka
#
# 10 --> Afghanistan
#
# 11 --> Netherlands
#
# 12 --> Ireland
#
# 13 --> Zimbabwe
#
# 14 --> Oman
#
# 15 --> Scotland
#
# 16 --> Nepal
#
# 17 --> UAE
#
# 18 --> Namibia
#
# 19 --> United States
#
# 20 --> Papua New Guinea

# %% [markdown]
# ### Project 3  [Fetching Images]

# %%
import requests 
from bs4 import BeautifulSoup
from PIL import Image

# %%
url = 'https://www.harpersbazaar.com/culture/film-tv/g36039508/best-2021-movies/'
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <title>
#    10 Best Movies 2021 - Best New Films of the Year
#   </title>
#   <meta charset="utf-8" name="charset"/>
#   <meta content="IE=edge,chrome=1" http_equiv="X-UA-Compatible" name="x-ua-compatible"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=6" name="viewport"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <meta content="#606060" name="theme-color"/>
#   <meta content="article" property="og:type"/>
#   <meta content="227018747326504" property="fb:app_id"/>
#   <meta content="https://www.facebook.com/HarpersBazaar" property="article:publisher"/>
#   <meta content="8327967561" property="fb:pages"/>
#   <meta content="@harpersbazaarus" name="twitter:site"/>
#   <meta content="bNUXKPTEqUVDbaxHrYA-c1kj007Ao4VsMKdoU80EyiU" name="google-site-verification"/>
#   <meta content="Harper's BAZAAR" property="og:site_name"/>
# ...

# %%
image = soup.find_all('img',{"alt":"best movies 2021"})

# %%
filterImages = []
for img in image:
    try:
        filterImages.append(img['src'])
    except:
        filterImages.append(img['data-src'])

# %%
filterImages
# Out:
# ['https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-malcolm-and-marie-netflix-1617727161.jpg?crop=1xw:1xh;center,top&resize=480:*',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-last-call-mutiny-pictures-1617727163.jpg?crop=1xw:1xh;center,top&resize=480:*',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-nina-wu-film-movement-1617727161.jpg?crop=1xw:1xh;center,top&resize=480:*',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-the-queen-of-black-magic-courtesy-1617727161.jpg?crop=1xw:1xh;center,top&resize=480:*',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-tatb3-netflix-1617727163.jpg?crop=1xw:1xh;center,top&resize=480:*',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/hbz-best-filmes-of-2021-the-vigil-everett-1617727163.jpg?crop=1xw:1xh;center,top&resize=480:*',
# ...

# %%
cin = input("Enter Image Number (0,9) -->")
im = None
try:
    if int(cin)>10 or int(cin)<0:
        print("Enter Right Code")
    else:
        im = Image.open(requests.get(filterImages[int(cin)], stream=True).raw)
except:
    print("Enter Right Code")

im
# Out:
# Enter Image Number (0,9) -->6
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x480 at 0x1F34D4BFF88>

# %% [markdown]
# ### Project 4  [Scrapping Stack OverFlow]

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="html__responsive html__fixed-top-bar" itemscope="" itemtype="https://schema.org/QAPage">
# <head>
# <title>datetime - How to get the current time in Python - Stack Overflow</title>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196" rel="shortcut icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="apple-touch-icon"/>
# <link href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a" rel="image_src"/>
# <link href="/opensearch.xml" rel="search" title="Stack Overflow" type="application/opensearchdescription+xml"/>
# <link href="https://stackoverflow.com/questions/415511/how-to-get-the-current-time-in-python" rel="canonical">
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="website" property="og:type">
# ...

# %%
answers = soup.find_all('div',{"class":"answer"})

# %%
answers
# Out:
# [<div class="answer accepted-answer" data-answerid="415519" data-ownerid="1057" data-score="3366" id="answer-415519" itemprop="acceptedAnswer" itemscope="" itemtype="https://schema.org/Answer">
#  <div class="post-layout">
#  <div class="votecell post-layout--left">
#  <div class="js-voting-container grid jc-center fd-column ai-stretch gs4 fc-black-200" data-post-id="415519">
#  <button aria-label="Up vote" aria-pressed="false" class="js-vote-up-btn grid--cell s-btn s-btn__unset c-pointer" data-controller="s-tooltip" data-s-tooltip-placement="right" data-selected-classes="fc-theme-primary" title="This answer is useful"><svg aria-hidden="true" class="m0 svg-icon iconArrowUpLg" height="36" viewbox="0 0 36 36" width="36"><path d="M2 26h32L18 10 2 26z"></path></svg></button>
#  <div class="js-vote-count grid--cell fc-black-500 fs-title grid fd-column ai-center" data-value="3366" itemprop="upvoteCount">3366</div>
# ...

# %%
for answer in answers:
    vote = answer.find('div',{"class":"js-vote-count"}).text
    if int(vote)>20:
        print(vote)
        codes = answer.find_all('pre')
        for code in codes:
            print(code.text)
    print("\n\n")
# Out:
# 3366
# >>> import datetime
# >>> datetime.datetime.now()
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
#
# >>> print(datetime.datetime.now())
# 2009-01-06 15:08:24.789150
#
# >>> datetime.datetime.now().time()
# datetime.time(15, 8, 24, 78915)
#
# >>> print(datetime.datetime.now().time())
# 15:08:24.789150
#
# >>> from datetime import datetime
#
#
#
#
# 1028
# >>> from time import gmtime, strftime
# >>> strftime("%Y-%m-%d %H:%M:%S", gmtime())
# '2009-01-05 22:14:39'
#
#
#
#
# 701
# from datetime import datetime
# datetime.now().strftime('%Y-%m-%d %H:%M:%S')
#
#
#
#
# 476
# >>> from datetime import datetime
# >>> str(datetime.now())
# '2011-05-03 17:45:35.177000'
#
#
#
#
# 416
# import time
#
# >>> time.time()
# 1424233311.771502
#
# >>> time.ctime()
# 'Tue Feb 17 23:21:56 2015'
#
# >>> time.ctime(1424233311.771502)
# 'Tue Feb 17 23:21:51 2015'
#
# >>> import datetime
#
# >>> datetime.datetime.now()
# datetime.datetime(2015, 2, 17, 23, 43, 49, 94252)
# ...
